# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('wine.data',header=None)
df.columns = [  'y'
                 ,'alcohol'
             	,'malicAcid'
             	,'ash'
            	,'ashalcalinity'
             	,'magnesium'
            	,'totalPhenols'
             	,'flavanoids'
             	,'nonFlavanoidPhenols'
             	,'proanthocyanins'
            	,'colorIntensity'
             	,'hue'
             	,'od280_od315'
             	,'proline'
                ]
df.head()
# Out:
#    y  alcohol  malicAcid   ash  ashalcalinity  magnesium  totalPhenols  \
# 0  1    14.23       1.71  2.43           15.6        127          2.80
# 1  1    13.20       1.78  2.14           11.2        100          2.65
# 2  1    13.16       2.36  2.67           18.6        101          2.80
# 3  1    14.37       1.95  2.50           16.8        113          3.85
# 4  1    13.24       2.59  2.87           21.0        118          2.80
#
#    flavanoids  nonFlavanoidPhenols  proanthocyanins  colorIntensity   hue  \
# 0        3.06                 0.28             2.29            5.64  1.04
# 1        2.76                 0.26             1.28            4.38  1.05
# 2        3.24                 0.30             2.81            5.68  1.03
# 3        3.49                 0.24             2.18            7.80  0.86
# 4        2.69                 0.39             1.82            4.32  1.04
#
#    od280_od315  proline
# 0         3.92     1065
# 1         3.40     1050
# ...

# %%
df['y'].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: y, dtype: int64

# %%
df.describe()
# Out:
#                 y     alcohol   malicAcid         ash  ashalcalinity  \
# count  178.000000  178.000000  178.000000  178.000000     178.000000
# mean     1.938202   13.000618    2.336348    2.366517      19.494944
# std      0.775035    0.811827    1.117146    0.274344       3.339564
# min      1.000000   11.030000    0.740000    1.360000      10.600000
# 25%      1.000000   12.362500    1.602500    2.210000      17.200000
# 50%      2.000000   13.050000    1.865000    2.360000      19.500000
# 75%      3.000000   13.677500    3.082500    2.557500      21.500000
# max      3.000000   14.830000    5.800000    3.230000      30.000000
#
#         magnesium  totalPhenols  flavanoids  nonFlavanoidPhenols  \
# count  178.000000    178.000000  178.000000           178.000000
# mean    99.741573      2.295112    2.029270             0.361854
# std     14.282484      0.625851    0.998859             0.124453
# min     70.000000      0.980000    0.340000             0.130000
# ...

# %%
def column_average(df, column):
    return df[column].mean()

print("%.3f" % column_average(df, 'alcohol'))
# Out:
# 13.001

# %%
def correlation(df, column1, column2):
    return df[column1].corr(df[column2])

# %%
print("%.3f" % correlation(df, 'alcohol', 'hue'))
# Out:
# -0.072

# %%
def std_pca(df, var=0.5):
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df)
    pca = PCA(var, random_state=100)
    X = df.drop('y', axis=1)
    X = pca.fit_transform(X)
    np.append(X, df['y'])
    return X

# %%
y = std_pca(df)[:,-1]
print(y.astype(int) == df['y'].values)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
# ...

# %%
pca = PCA()
X = df.drop('y', axis=1)
pca.fit(X)
pca.explained_variance_ratio_>0.85
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False, False, False, False])
